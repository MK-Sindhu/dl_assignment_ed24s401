# %% [markdown]
# #### ANSWER 7

# %%
from keras.datasets import mnist

# %% [markdown]
# #### ANSWER 8

# %%
import numpy as np
import wandb
from keras.datasets import fashion_mnist


# Neural Network Class: feed_forward_NN_4

class feed_forward_NN_8:
    def __init__(self,
                 layers,
                 optimizer,
                 learning_rate,
                 momentum,
                 beta1,
                 beta2,
                 beta,
                 epsilon,
                 weight_decay,
                 init_type,
                 activation,
                 loss_func
                 ):
    
        
        self.layers = layers
        self.layer_n = len(layers)
        self.optimizer = optimizer.lower()
        self.lr = learning_rate
        self.momentum = momentum
        self.beta1 = beta1
        self.beta2 = beta2
        self.beta = beta
        self.epsilon = epsilon
        self.weight_decay = weight_decay
        self.init_type = init_type.lower()
        self.activation = activation.lower()
        self.loss_func=loss_func.lower()

        # Initialize Weights & BiaseS
        self.weights = []
        self.biases = []
        for i in range(self.layer_n - 1):
            if self.init_type == "xavier":
                # "Xavier" initialization
                w = np.random.randn(layers[i], layers[i+1]) * np.sqrt(1.0 / layers[i])
            else:
                # "random" initialization
                w = np.random.randn(layers[i], layers[i+1]) * np.sqrt(2.0 / layers[i])
            b = np.zeros((1, layers[i+1]))
            self.weights.append(w)
            self.biases.append(b)

        # initialize extra Params 
        if self.optimizer in ["momentum", "nesterov", "rmsprop", "adam", "nadam"]:
            self.v_w = [np.zeros_like(w) for w in self.weights]
            self.v_b = [np.zeros_like(b) for b in self.biases]
        if self.optimizer in ["adam", "nadam"]:
            self.m_w = [np.zeros_like(w) for w in self.weights]
            self.m_b = [np.zeros_like(b) for b in self.biases]
            self.t = 0

    # activations 
    def sigmoid(self, x):
        return 1 / (1 + np.exp(-np.clip(x, -500, 500)))
    
    def tanh(self, x):
        return np.tanh(x)
    
    def relu(self, x):
        return np.maximum(0, x)

    def activate(self, x):
        if self.activation == "sigmoid":
            return self.sigmoid(x)
        elif self.activation == "tanh":
            return self.tanh(x)
        elif self.activation == "relu":
            return self.relu(x)
        else:
            return self.sigmoid(x) 
        
    # derivatives
    def derivative(self, a):

        if self.activation == "sigmoid":
            return a * (1 - a)
        elif self.activation == "tanh":
            return 1 - a**2
        elif self.activation == "relu":
            return (a > 0).astype(float)
        else:
            return a * (1 - a) 

    def softmax(self, x):
        exp_x = np.exp(x - np.max(x, axis=1, keepdims=True))
        return exp_x / np.sum(exp_x, axis=1, keepdims=True)

    # Forward Pass
    def forward_pass(self, x):
        self.h = [x]  
        # Hidden layers
        for i in range(self.layer_n - 2):
            z = np.dot(self.h[i], self.weights[i]) + self.biases[i]
            act = self.activate(z)
            self.h.append(act)
        # Output layer- softmax
        z_out = np.dot(self.h[-1], self.weights[-1]) + self.biases[-1]
        out = self.softmax(z_out)
        self.h.append(out)
        return self.h

    # Backward Pass
    def backward_prop(self, y_true):
        m = y_true.shape[0]
        dw = [None] * (self.layer_n - 1)
        db = [None] * (self.layer_n - 1)

        # Cross-entropy derivative for output layer
        if self.loss_func=="cross_entropy":
            delta = self.h[-1] - y_true  # shape: (batch_size, output_dim)
        elif self.loss_func=="sq_error":
            batch_size_sq=len(self.h[-1])
            classes_sq=len(self.h[-1][0])
            delta=np.zeros((batch_size_sq,classes_sq))

            for i in range(batch_size_sq):
                jacobian_softmax= np.diag(self.h[-1][i]) - np.outer(self.h[-1][i], self.h[-1][i])
                # print(jacobian_softmax.shape)
                # print(self.h[-1][i])    
                delta[i]= 2*np.dot(self.h[-1][i]-y_true[i], jacobian_softmax)
                
        else:
            delta = self.h[-1] - y_true 


        # Propagation
        for i in reversed(range(self.layer_n - 1)):
            dw[i] = np.dot(self.h[i].T, delta) / m
            db[i] = np.sum(delta, axis=0, keepdims=True) / m
            if i > 0:
                # For hidden layers, multiply by derivative of activation
                delta = np.dot(delta, self.weights[i].T) * self.derivative(self.h[i])
        return dw, db

    # Param Updates for "Non-Nesterov" 
    def _update_params(self, dw, db):
        # Add weight decay to each gradient
        for i in range(self.layer_n - 1):
            dw[i] += self.weight_decay * self.weights[i]

        if self.optimizer == "sgd":
            for i in range(self.layer_n - 1):
                self.weights[i] -= self.lr * dw[i]
                self.biases[i] -= self.lr * db[i]

        elif self.optimizer == "momentum":
            for i in range(self.layer_n - 1):
                self.v_w[i] = self.momentum * self.v_w[i] + dw[i]
                self.v_b[i] = self.momentum * self.v_b[i] + db[i]
                self.weights[i] -= self.lr * self.v_w[i]
                self.biases[i] -= self.lr * self.v_b[i]

        elif self.optimizer == "rmsprop":
            for i in range(self.layer_n - 1):
                self.v_w[i] = self.beta* self.v_w[i] + (1 - self.beta) * (dw[i] ** 2)
                self.v_b[i] = self.beta * self.v_b[i] + (1 - self.beta) * (db[i] ** 2)
                self.weights[i] -= self.lr * dw[i] / (np.sqrt(self.v_w[i]) + self.epsilon)
                self.biases[i]  -= self.lr * db[i] / (np.sqrt(self.v_b[i]) + self.epsilon)

        elif self.optimizer == "adam":
            self.t += 1
            for i in range(self.layer_n - 1):
                self.m_w[i] = self.beta1 * self.m_w[i] + (1 - self.beta1) * dw[i]
                self.m_b[i] = self.beta1 * self.m_b[i] + (1 - self.beta1) * db[i]
                self.v_w[i] = self.beta2 * self.v_w[i] + (1 - self.beta2) * (dw[i] ** 2)
                self.v_b[i] = self.beta2 * self.v_b[i] + (1 - self.beta2) * (db[i] ** 2)

                # bias correction
                m_w_hat = self.m_w[i] / (1 - self.beta1 ** self.t)
                m_b_hat = self.m_b[i] / (1 - self.beta1 ** self.t)
                v_w_hat = self.v_w[i] / (1 - self.beta2 ** self.t)
                v_b_hat = self.v_b[i] / (1 - self.beta2 ** self.t)

                self.weights[i] -= self.lr * m_w_hat / (np.sqrt(v_w_hat) + self.epsilon)
                self.biases[i]  -= self.lr * m_b_hat / (np.sqrt(v_b_hat) + self.epsilon)

        elif self.optimizer == "nadam":
            self.t += 1
            for i in range(self.layer_n - 1):
                self.m_w[i] = self.beta1 * self.m_w[i] + (1 - self.beta1) * dw[i]
                self.m_b[i] = self.beta1 * self.m_b[i] + (1 - self.beta1) * db[i]
                self.v_w[i] = self.beta2 * self.v_w[i] + (1 - self.beta2) * (dw[i] ** 2)
                self.v_b[i] = self.beta2 * self.v_b[i] + (1 - self.beta2) * (db[i] ** 2)

                # bias correction
                m_w_hat = self.m_w[i] / (1 - self.beta1 ** (self.t + 1))
                m_b_hat = self.m_b[i] / (1 - self.beta1 ** (self.t + 1))
                v_w_hat = self.v_w[i] / (1 - self.beta2 ** (self.t + 1))
                v_b_hat = self.v_b[i] / (1 - self.beta2 ** (self.t + 1))

                grad_term_w = self.beta1 * m_w_hat + (1 - self.beta1) * dw[i] / (1 - self.beta1 ** (self.t + 1))
                grad_term_b = self.beta1 * m_b_hat + (1 - self.beta1) * db[i] / (1 - self.beta1 ** (self.t + 1))

                self.weights[i] -= self.lr * grad_term_w / (np.sqrt(v_w_hat) + self.epsilon)
                self.biases[i]  -= self.lr * grad_term_b / (np.sqrt(v_b_hat) + self.epsilon)

    # Training Step  with "Nesterov"
    def _train_step(self, x_batch, y_batch):
        if self.optimizer == "nesterov":
            # to look-ahead: w_look = w - momentum * v
            for i in range(self.layer_n - 1):
                self.weights[i] -= self.lr*self.momentum * self.v_w[i]
                self.biases[i]  -= self.lr*self.momentum * self.v_b[i]

            # Forward at the look-ahead position
            self.forward_pass(x_batch)
            out = self.h[-1]
            l2_norm_weights = 0
            for i in range(len(self.weights)):
                l2_norm_weights += np.sum(self.weights[i] ** 2)
            # for i in range(len(self.biases)):
            #     l2_norm_bias += np.sum(self.biases[i] ** 2)
                    
            l2_norm_params = l2_norm_weights #+ l2_norm_bias

            if self.loss_func=="cross_entropy":
                loss = -np.mean(np.sum(y_batch * np.log(out + 1e-10), axis = 1)) +  (self.weight_decay/2) * l2_norm_params # (1e-10) to prevent underflow
            elif self.loss_func=="sq_error" :
                loss= 0.5 * np.mean(np.sum((out - y_batch)**2, axis=1))
            else:
                loss = -np.mean(np.sum(y_batch * np.log(out + 1e-10), axis = 1)) +  (self.weight_decay/2) * l2_norm_params
            
            
            #loss = -np.mean(np.sum(y_batch * np.log(out + 1e-10), axis = 1)) +  (self.weight_decay/2) * l2_norm_params # (1e-10) to prevent underflow
            #loss = -np.mean(np.sum(y_batch * np.log(out + 1e-10), axis=1))
            dW, dB = self.backward_prop(y_batch)

            # add weight decay here
            for i in range(self.layer_n - 1):
                dW[i] += self.weight_decay * self.weights[i]

            # backward at the look-ahead position (go back to w_t)
            for i in range(self.layer_n - 1):
                self.weights[i] += self.lr*self.momentum * self.v_w[i]
                self.biases[i]  += self.lr*self.momentum * self.v_b[i]

            # update velocity: u_t = momentum*u_{t-1} + dW
            for i in range(self.layer_n - 1):
                self.v_w[i] = self.momentum * self.v_w[i] + dW[i]
                self.v_b[i] = self.momentum * self.v_b[i] + dB[i]

            # final param update: w = w - lr*u_t
            for i in range(self.layer_n - 1):
                self.weights[i] -= self.lr * self.v_w[i]
                self.biases[i]  -= self.lr * self.v_b[i]

            return loss
        else:
            # Normal forward/back
            self.forward_pass(x_batch)
            out = self.h[-1]

            l2_norm_weights=0
            
            for i in range(len(self.weights)):
                l2_norm_weights += np.sum(self.weights[i] ** 2)
            # for i in range(len(self.biases)):
            #     l2_norm_bias += np.sum(self.biases[i] ** 2)
                    
            l2_norm_params = l2_norm_weights #+ l2_norm_bias

            if self.loss_func=="cross_entropy":
                loss = -np.mean(np.sum(y_batch * np.log(out + 1e-10), axis = 1)) +  (self.weight_decay/2) * l2_norm_params # (1e-10) to prevent underflow
            elif self.loss_func=="sq_error" :
                loss= 0.5 * np.mean(np.sum((out - y_batch)**2, axis=1))
            else:
                loss = -np.mean(np.sum(y_batch * np.log(out + 1e-10), axis = 1)) +  (self.weight_decay/2) * l2_norm_params    
            
            
             

            #loss = -np.mean(np.sum(y_batch * np.log(out + 1e-10), axis=1))
            dW, dB = self.backward_prop(y_batch)
            self._update_params(dW, dB)
            return loss

    # Outer Training Loop 
    def training(self, x_train, y_train, x_val, y_val, epochs, batch_size):
       
        for ep in range(epochs):
            idx = np.random.permutation(x_train.shape[0])
            x_train_shuff = x_train[idx]
            y_train_shuff = y_train[idx]
            n_batches = len(x_train) // batch_size
            epoch_loss = 0.0
            for b in range(n_batches):
                start = b * batch_size
                end = start + batch_size
                x_batch = x_train_shuff[start:end]
                y_batch = y_train_shuff[start:end]
                loss = self._train_step(x_batch, y_batch)
                epoch_loss += loss
            avg_loss = epoch_loss / n_batches

            # Validation

            preds = self.predict(x_val)
            val_labels = np.argmax(y_val, axis=1)
            val_acc = np.mean(preds == val_labels)

            val_outputs = self.forward_pass(x_val)[-1]
        
            # Cross-entropy loss for validation
            #val_loss = -np.mean(np.sum(y_val * np.log(val_outputs + 1e-10), axis=1))
            # training
            preds_train = self.predict(x_train)
            train_labels = np.argmax(y_train, axis=1)
            train_acc = np.mean(preds_train == train_labels)

            l2_norm_weights=0
            
            for i in range(len(self.weights)):
                l2_norm_weights += np.sum(self.weights[i] ** 2)
            # for i in range(len(self.biases)):
            #     l2_norm_bias += np.sum(self.biases[i] ** 2)
                    
            l2_norm_params = l2_norm_weights

            if self.loss_func=="cross_entropy":
                val_loss = -np.mean(np.sum(y_val * np.log(val_outputs + 1e-10), axis = 1)) +  (self.weight_decay/2) * l2_norm_params # (1e-10) to prevent underflow
            elif self.loss_func=="sq_error" :
                val_loss= 0.5 * np.mean(np.sum((val_outputs - y_val)**2, axis=1))
            else:
                val_loss = -np.mean(np.sum(y_val * np.log(val_outputs + 1e-10), axis = 1)) +  (self.weight_decay/2) * l2_norm_params

            # Log metrics to wandb
            wandb.log({"epoch": ep+1, "training_loss": avg_loss, "validation_accuracy": val_acc, "training accuracy": train_acc "validation loss": val_loss})
            print(f"Epoch {ep+1}/{epochs} - loss={avg_loss:.4f}, val_acc={val_acc:.4f}, val_loss={val_loss}" )

    #Prediction 
    def predict(self, X):
        self.forward_pass(X)
        return np.argmax(self.h[-1], axis=1)




# train_sweep() function

def train_sweep():
    # Initialize wandb
    wandb.init()
    config = wandb.config

    #custom run name from hyperparameters

    run_name = f"hl_{config.num_layers}_hs_{config.hidden_size}_bs_{config.batch_size}_ac_{config.activation}_opt_{config.optimizer}"
    wandb.run.name = run_name

    if config["dataset"] == "fashion_mnist":
        (x_train_full, y_train_full), (x_test, y_test) = fashion_mnist.load_data()
    else:  # "mnist"
        (x_train_full, y_train_full), (x_test, y_test) = mnist.load_data()

    x_train_full = x_train_full.reshape(x_train_full.shape[0], -1) / 255.0
    x_test = x_test.reshape(x_test.shape[0], -1) / 255.0

    np.random.seed(42)
    idx = np.arange(x_train_full.shape[0])
    np.random.shuffle(idx)
    x_train_full = x_train_full[idx]
    y_train_full = y_train_full[idx]

    # 90% train, 10% validation
    train_size = int(0.9 * len(x_train_full))
    x_train, y_train = x_train_full[:train_size], y_train_full[:train_size]
    x_val, y_val = x_train_full[train_size:], y_train_full[train_size:]

    num_classes = 10
    y_train_1h = np.eye(num_classes)[y_train]
    y_val_1h = np.eye(num_classes)[y_val]
    y_test_1h = np.eye(num_classes)[y_test]

    # Build model
    # layers = [784] + [hidden_size] * num_layers + [10]
    model = feed_forward_NN_8(
        layers=[784] + [config["hidden_size"]] * config["num_layers"] + [10],
        optimizer=config["optimizer"],
        learning_rate=config["learning_rate"],
        momentum=config["momentum"],
        beta1=config["beta1"],
        beta2=config["beta2"],
        beta=config["beta"],
        epsilon=config["epsilon"],
        weight_decay=config["weight_decay"],
        weight_init=config["weight_init"],
        activation=config["activation"],
        loss=config["loss"],
    )

    # Train
    model.training(
        x_train=x_train,
        y_train=y_train_1h,
        x_val=x_val,
        y_val=y_val_1h,
        epochs=config["epochs"],
        batch_size=config["batch_size"],
    )

    #Evaluation on test set
    test_preds = model.predict(x_test)
    test_labels = np.argmax(y_test_1h, axis=1)
    test_acc = np.mean(test_preds == test_labels)
    
    wandb.log({"test_accuracy": test_acc})
    print("test accuracy ",test_acc)


# sweep configuration
sweep_config = {
    "method": "random", 
    "metric": {
        "name": "validation_accuracy",
        "goal": "maximize"
    },
    "parameters": {
        "epochs": {"values": [5,10]},
        "num_layers": {"values": [3,4,5]},
        "hidden_size": {"values": [32,16,64]},
        "weight_decay": {"values": [0.0, 0.0005, 0.5]},
        "learning_rate": {"values": [1e-3, 1e-4]},
        "optimizer": {"values": ["sgd", "momentum", "nag", "rmsprop", "adam", "nadam"]},
        "batch_size": {"values": [32,64,128]},
        "init_type": {"values": ["random","xavier"]},
        "activation": {"values": [ "tanh", "relu"]},
        "momentum": {"values": [0.9]},
        "beta1": {"values": [0.9]},
        "beta2": {"values": [0.999]},
        "beta_rms": {"values": [0.9]},
        "epsilon": {"values": [1e-8]},
        "loss_func":{"values":["cross_entropy"]}
    }
}


# Running the sweep



if __name__ == "__main__":
    # Creating sweep
    sweep_id = wandb.sweep(sweep_config, project="q4_sweep_project")
    # Launching sweep agent
    wandb.agent(sweep_id, function=train_sweep)
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Create sweep with ID: g2aoqjdt
# Sweep URL: https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt
# wandb: Agent Starting Run: phf8zdp6 with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 64
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	beta_rms: 0.9
# wandb: 	epochs: 15
# wandb: 	epsilon: 1e-08
# wandb: 	hidden_size: 32
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: sq_error
# wandb: 	momentum: 0.9
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: rmsprop
# wandb: 	weight_decay: 0
# wandb: Currently logged in as: ed24s401 (ed24s401-indian-institute-of-technology-madras) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# creating run (0.3s)
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\acer\OneDrive\Documents\GitHub\dl_assignment_ed24s401\wandb\run-20250317_170503-phf8zdp6</code>
# Syncing run <strong><a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/phf8zdp6' target="_blank">fine-sweep-1</a></strong> to <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt</a>
#  View project at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a>
#  View sweep at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt</a>
#  View run at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/phf8zdp6' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/phf8zdp6</a>
# Epoch 1/15 - loss=0.2674, val_acc=0.7638, val_loss=0.1743751192722
# Epoch 2/15 - loss=0.1500, val_acc=0.8127, val_loss=0.14090028356791603
# Epoch 3/15 - loss=0.1293, val_acc=0.8278, val_loss=0.12823391681726123
# Epoch 4/15 - loss=0.1195, val_acc=0.8408, val_loss=0.11902486080913699
# Epoch 5/15 - loss=0.1134, val_acc=0.8455, val_loss=0.11426869310717432
# Epoch 6/15 - loss=0.1090, val_acc=0.8462, val_loss=0.11188272051937002
# Epoch 7/15 - loss=0.1058, val_acc=0.8507, val_loss=0.11078548537210581
# Epoch 8/15 - loss=0.1033, val_acc=0.8555, val_loss=0.10661031260267315
# Epoch 9/15 - loss=0.1010, val_acc=0.8540, val_loss=0.10798276465733196
# Epoch 10/15 - loss=0.0991, val_acc=0.8595, val_loss=0.10309541399735062
# Epoch 11/15 - loss=0.0971, val_acc=0.8573, val_loss=0.10286096169843634
# Epoch 12/15 - loss=0.0955, val_acc=0.8622, val_loss=0.10150745408797428
# Epoch 13/15 - loss=0.0941, val_acc=0.8645, val_loss=0.09836587726005193
# Epoch 14/15 - loss=0.0928, val_acc=0.8658, val_loss=0.09854203803645092
# Epoch 15/15 - loss=0.0915, val_acc=0.8578, val_loss=0.1018788919762487
# test accuracy  0.8513
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>training_loss</td><td>█▃▃▂▂▂▂▁▁▁▁▁▁▁▁</td></tr><tr><td>validation loss</td><td>█▅▄▃▂▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>validation_accuracy</td><td>▁▄▅▆▇▇▇▇▇█▇███▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>test_accuracy</td><td>0.8513</td></tr><tr><td>training_loss</td><td>0.09155</td></tr><tr><td>validation loss</td><td>0.10188</td></tr><tr><td>validation_accuracy</td><td>0.85783</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_3_hs_32_bs_64_ac_relu_opt_rmsprop</strong> at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/phf8zdp6' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/phf8zdp6</a><br> View project at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_170503-phf8zdp6\logs</code>
# wandb: Agent Starting Run: u237z7u1 with config:
# wandb: 	activation: tanh
# wandb: 	batch_size: 64
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	beta_rms: 0.9
# wandb: 	epochs: 15
# wandb: 	epsilon: 1e-08
# wandb: 	hidden_size: 32
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	momentum: 0.9
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: adam
# wandb: 	weight_decay: 0
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\acer\OneDrive\Documents\GitHub\dl_assignment_ed24s401\wandb\run-20250317_170612-u237z7u1</code>
# Syncing run <strong><a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/u237z7u1' target="_blank">vibrant-sweep-2</a></strong> to <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt</a>
#  View project at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a>
#  View sweep at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt</a>
#  View run at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/u237z7u1' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/u237z7u1</a>
# Epoch 1/15 - loss=0.5588, val_acc=0.8448, val_loss=0.4271538644512599
# Epoch 2/15 - loss=0.3943, val_acc=0.8480, val_loss=0.40445947172242025
# Epoch 3/15 - loss=0.3609, val_acc=0.8647, val_loss=0.3622889719636303
# Epoch 4/15 - loss=0.3390, val_acc=0.8708, val_loss=0.3485043947176629
# Epoch 5/15 - loss=0.3253, val_acc=0.8713, val_loss=0.35399132639249614
# Epoch 6/15 - loss=0.3102, val_acc=0.8805, val_loss=0.32743767254658884
# Epoch 7/15 - loss=0.3012, val_acc=0.8778, val_loss=0.33563633969756895
# Epoch 8/15 - loss=0.2913, val_acc=0.8673, val_loss=0.3643031518449673
# Epoch 9/15 - loss=0.2855, val_acc=0.8812, val_loss=0.32097279264277906
# Epoch 10/15 - loss=0.2787, val_acc=0.8770, val_loss=0.3393258879564772
# Epoch 11/15 - loss=0.2732, val_acc=0.8807, val_loss=0.3367238459348289
# Epoch 12/15 - loss=0.2634, val_acc=0.8760, val_loss=0.33319998529664646
# Epoch 13/15 - loss=0.2609, val_acc=0.8798, val_loss=0.33265992856267446
# Epoch 14/15 - loss=0.2546, val_acc=0.8857, val_loss=0.3187087963350519
# Epoch 15/15 - loss=0.2497, val_acc=0.8800, val_loss=0.3296278739239581
# test accuracy  0.8713
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>training_loss</td><td>█▄▄▃▃▂▂▂▂▂▂▁▁▁▁</td></tr><tr><td>validation loss</td><td>█▇▄▃▃▂▂▄▁▂▂▂▂▁▂</td></tr><tr><td>validation_accuracy</td><td>▁▂▄▅▆▇▇▅▇▇▇▆▇█▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>test_accuracy</td><td>0.8713</td></tr><tr><td>training_loss</td><td>0.24972</td></tr><tr><td>validation loss</td><td>0.32963</td></tr><tr><td>validation_accuracy</td><td>0.88</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_3_hs_32_bs_64_ac_tanh_opt_adam</strong> at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/u237z7u1' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/u237z7u1</a><br> View project at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_170612-u237z7u1\logs</code>
# wandb: Agent Starting Run: hkk486l4 with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 64
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	beta_rms: 0.9
# wandb: 	epochs: 15
# wandb: 	epsilon: 1e-08
# wandb: 	hidden_size: 32
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	momentum: 0.9
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: adam
# wandb: 	weight_decay: 0
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\acer\OneDrive\Documents\GitHub\dl_assignment_ed24s401\wandb\run-20250317_170711-hkk486l4</code>
# Syncing run <strong><a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/hkk486l4' target="_blank">iconic-sweep-3</a></strong> to <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt</a>
#  View project at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a>
#  View sweep at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt</a>
#  View run at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/hkk486l4' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/hkk486l4</a>
# Epoch 1/15 - loss=1.1280, val_acc=0.7710, val_loss=0.6874403469354357
# Epoch 2/15 - loss=0.5903, val_acc=0.8093, val_loss=0.5478209353920453
# Epoch 3/15 - loss=0.5036, val_acc=0.8313, val_loss=0.48710003291639853
# Epoch 4/15 - loss=0.4640, val_acc=0.8400, val_loss=0.459879015729208
# Epoch 5/15 - loss=0.4416, val_acc=0.8440, val_loss=0.4455406488407984
# Epoch 6/15 - loss=0.4243, val_acc=0.8527, val_loss=0.4266782544020839
# Epoch 7/15 - loss=0.4113, val_acc=0.8532, val_loss=0.4175954601943847
# Epoch 8/15 - loss=0.4017, val_acc=0.8563, val_loss=0.40938636345511836
# Epoch 9/15 - loss=0.3921, val_acc=0.8563, val_loss=0.40278812722555274
# Epoch 10/15 - loss=0.3844, val_acc=0.8590, val_loss=0.395092607387703
# Epoch 11/15 - loss=0.3772, val_acc=0.8623, val_loss=0.38809914083643315
# Epoch 12/15 - loss=0.3697, val_acc=0.8593, val_loss=0.3885536930151969
# Epoch 13/15 - loss=0.3639, val_acc=0.8633, val_loss=0.3797105619284139
# Epoch 14/15 - loss=0.3589, val_acc=0.8652, val_loss=0.37356018365124766
# Epoch 15/15 - loss=0.3530, val_acc=0.8657, val_loss=0.37165348232993256
# test accuracy  0.8597
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>training_loss</td><td>█▃▂▂▂▂▂▁▁▁▁▁▁▁▁</td></tr><tr><td>validation loss</td><td>█▅▄▃▃▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>validation_accuracy</td><td>▁▄▅▆▆▇▇▇▇██████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>test_accuracy</td><td>0.8597</td></tr><tr><td>training_loss</td><td>0.35299</td></tr><tr><td>validation loss</td><td>0.37165</td></tr><tr><td>validation_accuracy</td><td>0.86567</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_3_hs_32_bs_64_ac_relu_opt_adam</strong> at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/hkk486l4' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/hkk486l4</a><br> View project at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_170711-hkk486l4\logs</code>
# wandb: Agent Starting Run: 7eo6koov with config:
# wandb: 	activation: tanh
# wandb: 	batch_size: 64
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	beta_rms: 0.9
# wandb: 	epochs: 15
# wandb: 	epsilon: 1e-08
# wandb: 	hidden_size: 32
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	momentum: 0.9
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: rmsprop
# wandb: 	weight_decay: 0
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\acer\OneDrive\Documents\GitHub\dl_assignment_ed24s401\wandb\run-20250317_170819-7eo6koov</code>
# Syncing run <strong><a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/7eo6koov' target="_blank">stellar-sweep-4</a></strong> to <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt</a>
#  View project at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a>
#  View sweep at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt</a>
#  View run at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/7eo6koov' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/7eo6koov</a>
# Epoch 1/15 - loss=0.5558, val_acc=0.8328, val_loss=0.43777155646277605
# Epoch 2/15 - loss=0.4027, val_acc=0.8590, val_loss=0.3860200103252417
# Epoch 3/15 - loss=0.3684, val_acc=0.8703, val_loss=0.36221018302277114
# Epoch 4/15 - loss=0.3451, val_acc=0.8683, val_loss=0.36754871587464294
# Epoch 5/15 - loss=0.3293, val_acc=0.8677, val_loss=0.35029306676145977
# Epoch 6/15 - loss=0.3156, val_acc=0.8682, val_loss=0.35125727292328474
# Epoch 7/15 - loss=0.3063, val_acc=0.8582, val_loss=0.38536835636902395
# Epoch 8/15 - loss=0.2972, val_acc=0.8767, val_loss=0.3388813449871443
# Epoch 9/15 - loss=0.2906, val_acc=0.8737, val_loss=0.3436672801769622
# Epoch 10/15 - loss=0.2836, val_acc=0.8790, val_loss=0.32317606716566977
# Epoch 11/15 - loss=0.2767, val_acc=0.8710, val_loss=0.33245739693126186
# Epoch 12/15 - loss=0.2706, val_acc=0.8812, val_loss=0.33168192896185533
# Epoch 13/15 - loss=0.2654, val_acc=0.8838, val_loss=0.31609606544582625
# Epoch 14/15 - loss=0.2602, val_acc=0.8830, val_loss=0.3224808191262113
# Epoch 15/15 - loss=0.2558, val_acc=0.8777, val_loss=0.32547998104069514
# test accuracy  0.8687
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>training_loss</td><td>█▄▄▃▃▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>validation loss</td><td>█▅▄▄▃▃▅▂▃▁▂▂▁▁▂</td></tr><tr><td>validation_accuracy</td><td>▁▅▆▆▆▆▄▇▇▇▆███▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>test_accuracy</td><td>0.8687</td></tr><tr><td>training_loss</td><td>0.25581</td></tr><tr><td>validation loss</td><td>0.32548</td></tr><tr><td>validation_accuracy</td><td>0.87767</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_3_hs_32_bs_64_ac_tanh_opt_rmsprop</strong> at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/7eo6koov' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/7eo6koov</a><br> View project at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_170819-7eo6koov\logs</code>
# wandb: Agent Starting Run: 7bims42w with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 64
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	beta_rms: 0.9
# wandb: 	epochs: 15
# wandb: 	epsilon: 1e-08
# wandb: 	hidden_size: 32
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: sq_error
# wandb: 	momentum: 0.9
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: adam
# wandb: 	weight_decay: 0
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\acer\OneDrive\Documents\GitHub\dl_assignment_ed24s401\wandb\run-20250317_170906-7bims42w</code>
# Syncing run <strong><a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/7bims42w' target="_blank">curious-sweep-5</a></strong> to <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt</a>
#  View project at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a>
#  View sweep at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt</a>
#  View run at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/7bims42w' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/7bims42w</a>
# Epoch 1/15 - loss=0.2508, val_acc=0.7885, val_loss=0.15991361816997302
# Epoch 2/15 - loss=0.1409, val_acc=0.8227, val_loss=0.1339766734499667
# Epoch 3/15 - loss=0.1235, val_acc=0.8362, val_loss=0.12235040903217013
# Epoch 4/15 - loss=0.1152, val_acc=0.8407, val_loss=0.11602632680767191
# Epoch 5/15 - loss=0.1101, val_acc=0.8485, val_loss=0.1111943736075314
# Epoch 6/15 - loss=0.1061, val_acc=0.8497, val_loss=0.10889108678250492
# Epoch 7/15 - loss=0.1030, val_acc=0.8548, val_loss=0.10599378831103562
# Epoch 8/15 - loss=0.1006, val_acc=0.8590, val_loss=0.10350006496157217
# Epoch 9/15 - loss=0.0983, val_acc=0.8617, val_loss=0.10252062173030667
# Epoch 10/15 - loss=0.0964, val_acc=0.8615, val_loss=0.10153151535661716
# Epoch 11/15 - loss=0.0947, val_acc=0.8625, val_loss=0.09942441967314822
# Epoch 12/15 - loss=0.0929, val_acc=0.8647, val_loss=0.0992691619963896
# Epoch 13/15 - loss=0.0916, val_acc=0.8675, val_loss=0.09794821775890449
# Epoch 14/15 - loss=0.0903, val_acc=0.8682, val_loss=0.09633445285695712
# Epoch 15/15 - loss=0.0889, val_acc=0.8645, val_loss=0.09731387253269258
# test accuracy  0.8588
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>training_loss</td><td>█▃▂▂▂▂▂▂▁▁▁▁▁▁▁</td></tr><tr><td>validation loss</td><td>█▅▄▃▃▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>validation_accuracy</td><td>▁▄▅▆▆▆▇▇▇▇█████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>test_accuracy</td><td>0.8588</td></tr><tr><td>training_loss</td><td>0.08889</td></tr><tr><td>validation loss</td><td>0.09731</td></tr><tr><td>validation_accuracy</td><td>0.8645</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_3_hs_32_bs_64_ac_relu_opt_adam</strong> at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/7bims42w' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/7bims42w</a><br> View project at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_170906-7bims42w\logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: gwswzsix with config:
# wandb: 	activation: tanh
# wandb: 	batch_size: 64
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	beta_rms: 0.9
# wandb: 	epochs: 15
# wandb: 	epsilon: 1e-08
# wandb: 	hidden_size: 32
# wandb: 	init_type: xavier
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	momentum: 0.9
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: adam
# wandb: 	weight_decay: 0
# creating run (0.3s)
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\acer\OneDrive\Documents\GitHub\dl_assignment_ed24s401\wandb\run-20250317_171014-gwswzsix</code>
# Syncing run <strong><a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/gwswzsix' target="_blank">worldly-sweep-6</a></strong> to <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt</a>
#  View project at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a>
#  View sweep at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt</a>
#  View run at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/gwswzsix' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/gwswzsix</a>
# Epoch 1/15 - loss=0.5847, val_acc=0.8423, val_loss=0.4223828706648879
# Epoch 2/15 - loss=0.3954, val_acc=0.8545, val_loss=0.3912485599404234
# Epoch 3/15 - loss=0.3605, val_acc=0.8673, val_loss=0.3556274217469379
# Epoch 4/15 - loss=0.3403, val_acc=0.8665, val_loss=0.3574887546508234
# Epoch 5/15 - loss=0.3259, val_acc=0.8678, val_loss=0.365927484966705
# Epoch 6/15 - loss=0.3097, val_acc=0.8770, val_loss=0.32927511615321914
# Epoch 7/15 - loss=0.2998, val_acc=0.8787, val_loss=0.32379152470487654
# Epoch 8/15 - loss=0.2898, val_acc=0.8635, val_loss=0.3650505127536943
# Epoch 9/15 - loss=0.2851, val_acc=0.8810, val_loss=0.31823920240703
# Epoch 10/15 - loss=0.2764, val_acc=0.8787, val_loss=0.33518423769134087
# Epoch 11/15 - loss=0.2713, val_acc=0.8768, val_loss=0.3297460155598525
# Epoch 12/15 - loss=0.2614, val_acc=0.8833, val_loss=0.3264488395338764
# Epoch 13/15 - loss=0.2580, val_acc=0.8865, val_loss=0.32119755011907447
# Epoch 14/15 - loss=0.2532, val_acc=0.8832, val_loss=0.3204723575858921
# Epoch 15/15 - loss=0.2472, val_acc=0.8783, val_loss=0.33043635087155443
# test accuracy  0.8704
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>training_loss</td><td>█▄▃▃▃▂▂▂▂▂▂▁▁▁▁</td></tr><tr><td>validation loss</td><td>█▆▄▄▄▂▁▄▁▂▂▂▁▁▂</td></tr><tr><td>validation_accuracy</td><td>▁▃▅▅▅▆▇▄▇▇▆▇█▇▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>test_accuracy</td><td>0.8704</td></tr><tr><td>training_loss</td><td>0.24719</td></tr><tr><td>validation loss</td><td>0.33044</td></tr><tr><td>validation_accuracy</td><td>0.87833</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_3_hs_32_bs_64_ac_tanh_opt_adam</strong> at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/gwswzsix' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/gwswzsix</a><br> View project at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_171014-gwswzsix\logs</code>
# wandb: Agent Starting Run: 9uczbktc with config:
# wandb: 	activation: tanh
# wandb: 	batch_size: 64
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	beta_rms: 0.9
# wandb: 	epochs: 15
# wandb: 	epsilon: 1e-08
# wandb: 	hidden_size: 32
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: sq_error
# wandb: 	momentum: 0.9
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: adam
# wandb: 	weight_decay: 0
# creating run (0.2s)
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\acer\OneDrive\Documents\GitHub\dl_assignment_ed24s401\wandb\run-20250317_171058-9uczbktc</code>
# Syncing run <strong><a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/9uczbktc' target="_blank">stoic-sweep-7</a></strong> to <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt</a>
#  View project at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a>
#  View sweep at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt</a>
#  View run at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/9uczbktc' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/9uczbktc</a>
# Epoch 1/15 - loss=0.2262, val_acc=0.7972, val_loss=0.15340633505537074
# Epoch 2/15 - loss=0.1351, val_acc=0.8230, val_loss=0.12849873562126413
# Epoch 3/15 - loss=0.1186, val_acc=0.8365, val_loss=0.11654167326939735
# Epoch 4/15 - loss=0.1104, val_acc=0.8438, val_loss=0.1116252541829645
# Epoch 5/15 - loss=0.1056, val_acc=0.8525, val_loss=0.10642589802703982
# Epoch 6/15 - loss=0.1016, val_acc=0.8510, val_loss=0.10472057925021
# Epoch 7/15 - loss=0.0987, val_acc=0.8575, val_loss=0.10131341121112283
# Epoch 8/15 - loss=0.0963, val_acc=0.8600, val_loss=0.09995529280625355
# Epoch 9/15 - loss=0.0943, val_acc=0.8628, val_loss=0.09797341864225681
# Epoch 10/15 - loss=0.0926, val_acc=0.8635, val_loss=0.09862472186706352
# Epoch 11/15 - loss=0.0912, val_acc=0.8643, val_loss=0.09677629532947156
# Epoch 12/15 - loss=0.0895, val_acc=0.8667, val_loss=0.09631917740106112
# Epoch 13/15 - loss=0.0884, val_acc=0.8690, val_loss=0.09333225153615081
# Epoch 14/15 - loss=0.0872, val_acc=0.8700, val_loss=0.09374016410840073
# Epoch 15/15 - loss=0.0860, val_acc=0.8687, val_loss=0.0937031295092617
# test accuracy  0.8624
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>training_loss</td><td>█▃▃▂▂▂▂▂▁▁▁▁▁▁▁</td></tr><tr><td>validation loss</td><td>█▅▄▃▃▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>validation_accuracy</td><td>▁▃▅▅▆▆▇▇▇▇▇████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>test_accuracy</td><td>0.8624</td></tr><tr><td>training_loss</td><td>0.086</td></tr><tr><td>validation loss</td><td>0.0937</td></tr><tr><td>validation_accuracy</td><td>0.86867</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_3_hs_32_bs_64_ac_tanh_opt_adam</strong> at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/9uczbktc' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/9uczbktc</a><br> View project at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_171058-9uczbktc\logs</code>
# wandb: Agent Starting Run: 0cz8wsny with config:
# wandb: 	activation: tanh
# wandb: 	batch_size: 64
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	beta_rms: 0.9
# wandb: 	epochs: 15
# wandb: 	epsilon: 1e-08
# wandb: 	hidden_size: 32
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: sq_error
# wandb: 	momentum: 0.9
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: adam
# wandb: 	weight_decay: 0
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\acer\OneDrive\Documents\GitHub\dl_assignment_ed24s401\wandb\run-20250317_171156-0cz8wsny</code>
# Syncing run <strong><a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/0cz8wsny' target="_blank">woven-sweep-8</a></strong> to <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt</a>
#  View project at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a>
#  View sweep at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt</a>
#  View run at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/0cz8wsny' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/0cz8wsny</a>
# Epoch 1/15 - loss=0.2262, val_acc=0.7972, val_loss=0.15340633505537074
# Epoch 2/15 - loss=0.1351, val_acc=0.8230, val_loss=0.12849873562126413
# Epoch 3/15 - loss=0.1186, val_acc=0.8365, val_loss=0.11654167326939735
# Epoch 4/15 - loss=0.1104, val_acc=0.8438, val_loss=0.1116252541829645
# Epoch 5/15 - loss=0.1056, val_acc=0.8525, val_loss=0.10642589802703982
# Epoch 6/15 - loss=0.1016, val_acc=0.8510, val_loss=0.10472057925021
# Epoch 7/15 - loss=0.0987, val_acc=0.8575, val_loss=0.10131341121112283
# Epoch 8/15 - loss=0.0963, val_acc=0.8600, val_loss=0.09995529280625355
# Epoch 9/15 - loss=0.0943, val_acc=0.8628, val_loss=0.09797341864225681
# Epoch 10/15 - loss=0.0926, val_acc=0.8635, val_loss=0.09862472186706352
# Epoch 11/15 - loss=0.0912, val_acc=0.8643, val_loss=0.09677629532947156
# Epoch 12/15 - loss=0.0895, val_acc=0.8667, val_loss=0.09631917740106112
# Epoch 13/15 - loss=0.0884, val_acc=0.8690, val_loss=0.09333225153615081
# Epoch 14/15 - loss=0.0872, val_acc=0.8700, val_loss=0.09374016410840073
# Epoch 15/15 - loss=0.0860, val_acc=0.8687, val_loss=0.0937031295092617
# test accuracy  0.8624
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>training_loss</td><td>█▃▃▂▂▂▂▂▁▁▁▁▁▁▁</td></tr><tr><td>validation loss</td><td>█▅▄▃▃▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>validation_accuracy</td><td>▁▃▅▅▆▆▇▇▇▇▇████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>test_accuracy</td><td>0.8624</td></tr><tr><td>training_loss</td><td>0.086</td></tr><tr><td>validation loss</td><td>0.0937</td></tr><tr><td>validation_accuracy</td><td>0.86867</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_3_hs_32_bs_64_ac_tanh_opt_adam</strong> at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/0cz8wsny' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/0cz8wsny</a><br> View project at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_171156-0cz8wsny\logs</code>
# wandb: Agent Starting Run: b90msnl2 with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 64
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	beta_rms: 0.9
# wandb: 	epochs: 15
# wandb: 	epsilon: 1e-08
# wandb: 	hidden_size: 32
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: sq_error
# wandb: 	momentum: 0.9
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: rmsprop
# wandb: 	weight_decay: 0
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\acer\OneDrive\Documents\GitHub\dl_assignment_ed24s401\wandb\run-20250317_171254-b90msnl2</code>
# Syncing run <strong><a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/b90msnl2' target="_blank">zany-sweep-9</a></strong> to <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt</a>
#  View project at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a>
#  View sweep at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt</a>
#  View run at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/b90msnl2' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/b90msnl2</a>
# Epoch 1/15 - loss=0.1524, val_acc=0.8313, val_loss=0.1245255895745075
# Epoch 2/15 - loss=0.1118, val_acc=0.8493, val_loss=0.10794346530513453
# Epoch 3/15 - loss=0.1019, val_acc=0.8608, val_loss=0.10114784327619517
# Epoch 4/15 - loss=0.0959, val_acc=0.8623, val_loss=0.0987054971601063
# Epoch 5/15 - loss=0.0916, val_acc=0.8738, val_loss=0.09158856352115755
# Epoch 6/15 - loss=0.0883, val_acc=0.8640, val_loss=0.09430304095777431
# Epoch 7/15 - loss=0.0862, val_acc=0.8655, val_loss=0.10152089438475206
# Epoch 8/15 - loss=0.0835, val_acc=0.8730, val_loss=0.09048963897219622
# Epoch 9/15 - loss=0.0821, val_acc=0.8745, val_loss=0.08900585688577257
# Epoch 10/15 - loss=0.0799, val_acc=0.8692, val_loss=0.09298489125222162
# Epoch 11/15 - loss=0.0777, val_acc=0.8758, val_loss=0.0892168823899104
# Epoch 12/15 - loss=0.0771, val_acc=0.8790, val_loss=0.08838762237306609
# Epoch 13/15 - loss=0.0758, val_acc=0.8842, val_loss=0.08579004300847413
# Epoch 14/15 - loss=0.0741, val_acc=0.8825, val_loss=0.08606499442054288
# Epoch 15/15 - loss=0.0734, val_acc=0.8825, val_loss=0.08511525860089889
# test accuracy  0.8724
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>training_loss</td><td>█▄▄▃▃▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>validation loss</td><td>█▅▄▃▂▃▄▂▂▂▂▂▁▁▁</td></tr><tr><td>validation_accuracy</td><td>▁▃▅▅▇▅▆▇▇▆▇▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>test_accuracy</td><td>0.8724</td></tr><tr><td>training_loss</td><td>0.07339</td></tr><tr><td>validation loss</td><td>0.08512</td></tr><tr><td>validation_accuracy</td><td>0.8825</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_3_hs_32_bs_64_ac_relu_opt_rmsprop</strong> at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/b90msnl2' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/b90msnl2</a><br> View project at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_171254-b90msnl2\logs</code>
# wandb: Agent Starting Run: 6wz5blpo with config:
# wandb: 	activation: tanh
# wandb: 	batch_size: 64
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	beta_rms: 0.9
# wandb: 	epochs: 15
# wandb: 	epsilon: 1e-08
# wandb: 	hidden_size: 32
# wandb: 	init_type: xavier
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: sq_error
# wandb: 	momentum: 0.9
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: adam
# wandb: 	weight_decay: 0
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\acer\OneDrive\Documents\GitHub\dl_assignment_ed24s401\wandb\run-20250317_171342-6wz5blpo</code>
# Syncing run <strong><a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/6wz5blpo' target="_blank">upbeat-sweep-10</a></strong> to <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt</a>
#  View project at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a>
#  View sweep at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt</a>
#  View run at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/6wz5blpo' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/6wz5blpo</a>
# Epoch 1/15 - loss=0.2557, val_acc=0.7805, val_loss=0.1707722580727658
# Epoch 2/15 - loss=0.1444, val_acc=0.8188, val_loss=0.1329447690918598
# Epoch 3/15 - loss=0.1219, val_acc=0.8345, val_loss=0.1195483380835641
# Epoch 4/15 - loss=0.1125, val_acc=0.8422, val_loss=0.11316655820370497
# Epoch 5/15 - loss=0.1070, val_acc=0.8470, val_loss=0.10848648750904173
# Epoch 6/15 - loss=0.1027, val_acc=0.8533, val_loss=0.10580834427994996
# Epoch 7/15 - loss=0.0995, val_acc=0.8598, val_loss=0.10260613500171341
# Epoch 8/15 - loss=0.0971, val_acc=0.8607, val_loss=0.10063556806982776
# Epoch 9/15 - loss=0.0948, val_acc=0.8617, val_loss=0.09884146377346889
# Epoch 10/15 - loss=0.0930, val_acc=0.8623, val_loss=0.09955211952367332
# Epoch 11/15 - loss=0.0915, val_acc=0.8637, val_loss=0.09715185716357451
# Epoch 12/15 - loss=0.0897, val_acc=0.8650, val_loss=0.09731779821621647
# Epoch 13/15 - loss=0.0885, val_acc=0.8693, val_loss=0.09411591335441452
# Epoch 14/15 - loss=0.0873, val_acc=0.8658, val_loss=0.09497111199991268
# Epoch 15/15 - loss=0.0861, val_acc=0.8680, val_loss=0.09471605862810965
# test accuracy  0.8636
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>training_loss</td><td>█▃▂▂▂▂▂▁▁▁▁▁▁▁▁</td></tr><tr><td>validation loss</td><td>█▅▃▃▂▂▂▂▁▁▁▁▁▁▁</td></tr><tr><td>validation_accuracy</td><td>▁▄▅▆▆▇▇▇▇▇█████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>test_accuracy</td><td>0.8636</td></tr><tr><td>training_loss</td><td>0.08612</td></tr><tr><td>validation loss</td><td>0.09472</td></tr><tr><td>validation_accuracy</td><td>0.868</td></tr></table><br/></div></div>
# ...
#  View run <strong style="color:#cdcd00">hl_3_hs_32_bs_64_ac_tanh_opt_adam</strong> at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/mqe1hba5' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/mqe1hba5</a><br> View project at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_185100-mqe1hba5\logs</code>
# wandb: Agent Starting Run: 7m8n7cnh with config:
# wandb: 	activation: tanh
# wandb: 	batch_size: 64
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	beta_rms: 0.9
# wandb: 	epochs: 15
# wandb: 	epsilon: 1e-08
# wandb: 	hidden_size: 32
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: sq_error
# wandb: 	momentum: 0.9
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: rmsprop
# wandb: 	weight_decay: 0
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\acer\OneDrive\Documents\GitHub\dl_assignment_ed24s401\wandb\run-20250317_185133-7m8n7cnh</code>
# Syncing run <strong><a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/7m8n7cnh' target="_blank">earthy-sweep-170</a></strong> to <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt</a>
#  View project at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a>
#  View sweep at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt</a>
#  View run at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/7m8n7cnh' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/7m8n7cnh</a>
# Epoch 1/15 - loss=0.1397, val_acc=0.8355, val_loss=0.11350597836975147
# Epoch 2/15 - loss=0.1057, val_acc=0.8588, val_loss=0.10112544991042209
# Epoch 3/15 - loss=0.0971, val_acc=0.8688, val_loss=0.09539135940287359
# Epoch 4/15 - loss=0.0914, val_acc=0.8623, val_loss=0.09890848436977485
# Epoch 5/15 - loss=0.0877, val_acc=0.8713, val_loss=0.09307759306069037
# Epoch 6/15 - loss=0.0842, val_acc=0.8645, val_loss=0.09620183190547767
# Epoch 7/15 - loss=0.0824, val_acc=0.8698, val_loss=0.09265516953815112
# Epoch 8/15 - loss=0.0803, val_acc=0.8785, val_loss=0.08747185659491241
# Epoch 9/15 - loss=0.0784, val_acc=0.8743, val_loss=0.09149474544387273
# Epoch 10/15 - loss=0.0767, val_acc=0.8785, val_loss=0.08797854065202694
# Epoch 11/15 - loss=0.0754, val_acc=0.8757, val_loss=0.08909678934648581
# Epoch 12/15 - loss=0.0739, val_acc=0.8755, val_loss=0.08976308206757432
# Epoch 13/15 - loss=0.0721, val_acc=0.8727, val_loss=0.09255991391862062
# Epoch 14/15 - loss=0.0712, val_acc=0.8808, val_loss=0.08545360661998516
# Epoch 15/15 - loss=0.0701, val_acc=0.8792, val_loss=0.08632901616772197
# test accuracy  0.8726
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>training_loss</td><td>█▅▄▃▃▂▂▂▂▂▂▁▁▁▁</td></tr><tr><td>validation loss</td><td>█▅▃▄▃▄▃▂▃▂▂▂▃▁▁</td></tr><tr><td>validation_accuracy</td><td>▁▅▆▅▇▅▆█▇█▇▇▇██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>test_accuracy</td><td>0.8726</td></tr><tr><td>training_loss</td><td>0.07011</td></tr><tr><td>validation loss</td><td>0.08633</td></tr><tr><td>validation_accuracy</td><td>0.87917</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_3_hs_32_bs_64_ac_tanh_opt_rmsprop</strong> at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/7m8n7cnh' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/7m8n7cnh</a><br> View project at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_185133-7m8n7cnh\logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: ndwwl9x7 with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 64
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	beta_rms: 0.9
# wandb: 	epochs: 15
# wandb: 	epsilon: 1e-08
# wandb: 	hidden_size: 32
# wandb: 	init_type: xavier
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	momentum: 0.9
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: rmsprop
# wandb: 	weight_decay: 0
# creating run (0.0s)
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\acer\OneDrive\Documents\GitHub\dl_assignment_ed24s401\wandb\run-20250317_185220-ndwwl9x7</code>
# Syncing run <strong><a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/ndwwl9x7' target="_blank">bumbling-sweep-171</a></strong> to <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt</a>
#  View project at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a>
#  View sweep at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt</a>
#  View run at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/ndwwl9x7' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/ndwwl9x7</a>
# Epoch 1/15 - loss=0.6259, val_acc=0.8292, val_loss=0.46986892883264325
# Epoch 2/15 - loss=0.4350, val_acc=0.8482, val_loss=0.40931900197957294
# Epoch 3/15 - loss=0.3933, val_acc=0.8610, val_loss=0.3929496971886448
# Epoch 4/15 - loss=0.3677, val_acc=0.8625, val_loss=0.38100447920381475
# Epoch 5/15 - loss=0.3505, val_acc=0.8697, val_loss=0.34861474358761296
# Epoch 6/15 - loss=0.3366, val_acc=0.8655, val_loss=0.3651900360971135
# Epoch 7/15 - loss=0.3265, val_acc=0.8460, val_loss=0.44542384190344814
# Epoch 8/15 - loss=0.3173, val_acc=0.8730, val_loss=0.34927960227979377
# Epoch 9/15 - loss=0.3099, val_acc=0.8582, val_loss=0.38767435174390713
# Epoch 10/15 - loss=0.3022, val_acc=0.8687, val_loss=0.3559346085114018
# Epoch 11/15 - loss=0.2968, val_acc=0.8705, val_loss=0.3537828276951274
# Epoch 12/15 - loss=0.2914, val_acc=0.8787, val_loss=0.33658602607240146
# Epoch 13/15 - loss=0.2865, val_acc=0.8823, val_loss=0.32385177927827774
# Epoch 14/15 - loss=0.2823, val_acc=0.8757, val_loss=0.3449483972933062
# Epoch 15/15 - loss=0.2768, val_acc=0.8700, val_loss=0.3551525097568817
# test accuracy  0.8634
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>training_loss</td><td>█▄▃▃▂▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>validation loss</td><td>█▅▄▄▂▃▇▂▄▃▂▂▁▂▃</td></tr><tr><td>validation_accuracy</td><td>▁▄▅▅▆▆▃▇▅▆▆██▇▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>test_accuracy</td><td>0.8634</td></tr><tr><td>training_loss</td><td>0.27677</td></tr><tr><td>validation loss</td><td>0.35515</td></tr><tr><td>validation_accuracy</td><td>0.87</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_3_hs_32_bs_64_ac_relu_opt_rmsprop</strong> at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/ndwwl9x7' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/ndwwl9x7</a><br> View project at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_185220-ndwwl9x7\logs</code>
# wandb: Agent Starting Run: m08trzzk with config:
# wandb: 	activation: tanh
# wandb: 	batch_size: 64
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	beta_rms: 0.9
# wandb: 	epochs: 15
# wandb: 	epsilon: 1e-08
# wandb: 	hidden_size: 32
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: sq_error
# wandb: 	momentum: 0.9
# wandb: 	num_hidden_layers: 3
# wandb: 	optimizer: adam
# wandb: 	weight_decay: 0
# creating run (0.2s)
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\acer\OneDrive\Documents\GitHub\dl_assignment_ed24s401\wandb\run-20250317_185247-m08trzzk</code>
# Syncing run <strong><a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/m08trzzk' target="_blank">jumping-sweep-172</a></strong> to <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt</a>
#  View project at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a>
#  View sweep at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/g2aoqjdt</a>
#  View run at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/m08trzzk' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/m08trzzk</a>
# Epoch 1/15 - loss=0.1376, val_acc=0.8423, val_loss=0.11112433564752147
# Epoch 2/15 - loss=0.1025, val_acc=0.8477, val_loss=0.10777411884002344
# Epoch 3/15 - loss=0.0945, val_acc=0.8620, val_loss=0.09892814536193184
# Epoch 4/15 - loss=0.0897, val_acc=0.8653, val_loss=0.09418991352338693
# Epoch 5/15 - loss=0.0857, val_acc=0.8710, val_loss=0.09264558895498605
# Epoch 6/15 - loss=0.0821, val_acc=0.8667, val_loss=0.09416271172475506
# Epoch 7/15 - loss=0.0797, val_acc=0.8743, val_loss=0.08965335280493393
# Epoch 8/15 - loss=0.0772, val_acc=0.8610, val_loss=0.09858342616893281
# Epoch 9/15 - loss=0.0767, val_acc=0.8818, val_loss=0.08504300356954755
# Epoch 10/15 - loss=0.0739, val_acc=0.8742, val_loss=0.08980353038586741
# Epoch 11/15 - loss=0.0732, val_acc=0.8777, val_loss=0.08927301549656505
# Epoch 12/15 - loss=0.0709, val_acc=0.8768, val_loss=0.08852451372980254
# Epoch 13/15 - loss=0.0700, val_acc=0.8782, val_loss=0.08840949088910666
# Epoch 14/15 - loss=0.0688, val_acc=0.8818, val_loss=0.08668242368013991
# Epoch 15/15 - loss=0.0682, val_acc=0.8717, val_loss=0.09067734944943008
# test accuracy  0.868
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>training_loss</td><td>█▄▄▃▃▂▂▂▂▂▂▁▁▁▁</td></tr><tr><td>validation loss</td><td>█▇▅▃▃▃▂▅▁▂▂▂▂▁▃</td></tr><tr><td>validation_accuracy</td><td>▁▂▄▅▆▅▇▄█▇▇▇▇█▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>test_accuracy</td><td>0.868</td></tr><tr><td>training_loss</td><td>0.06824</td></tr><tr><td>validation loss</td><td>0.09068</td></tr><tr><td>validation_accuracy</td><td>0.87167</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hl_3_hs_32_bs_64_ac_tanh_opt_adam</strong> at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/m08trzzk' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/m08trzzk</a><br> View project at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_185247-m08trzzk\logs</code>
# wandb: Ctrl + C detected. Stopping sweep.

# %%
import numpy as np
import wandb
from keras.datasets import fashion_mnist


# Neural Network Class: feed_forward_NN_4

class feed_forward_NN_8b:
    def __init__(self,
                 layers,
                 optimizer,
                 learning_rate,
                 momentum,
                 beta1,
                 beta2,
                 beta,
                 epsilon,
                 weight_decay,
                 init_type,
                 activation,
                 loss_func
                 ):
    
        
        self.layers = layers
        self.layer_n = len(layers)
        self.optimizer = optimizer.lower()
        self.lr = learning_rate
        self.momentum = momentum
        self.beta1 = beta1
        self.beta2 = beta2
        self.beta= beta
        self.epsilon = epsilon
        self.weight_decay = weight_decay
        self.init_type = init_type.lower()
        self.activation = activation.lower()
        self.loss_func=loss_func.lower()

        # Initialize Weights & BiaseS
        self.weights = []
        self.biases = []
        for i in range(self.layer_n - 1):
            if self.init_type == "xavier":
                # "Xavier" initialization
                w = np.random.randn(layers[i], layers[i+1]) * np.sqrt(1.0 / layers[i])
            else:
                # "random" initialization
                w = np.random.randn(layers[i], layers[i+1]) * np.sqrt(2.0 / layers[i])
            b = np.zeros((1, layers[i+1]))
            self.weights.append(w)
            self.biases.append(b)

        # initialize extra Params 
        if self.optimizer in ["momentum", "nesterov", "rmsprop", "adam", "nadam"]:
            self.v_w = [np.zeros_like(w) for w in self.weights]
            self.v_b = [np.zeros_like(b) for b in self.biases]
        if self.optimizer in ["adam", "nadam"]:
            self.m_w = [np.zeros_like(w) for w in self.weights]
            self.m_b = [np.zeros_like(b) for b in self.biases]
            self.t = 0

    # activations 
    def sigmoid(self, x):
        return 1 / (1 + np.exp(-np.clip(x, -500, 500)))
    
    def tanh(self, x):
        return np.tanh(x)
    
    def relu(self, x):
        return np.maximum(0, x)

    def activate(self, x):
        if self.activation == "sigmoid":
            return self.sigmoid(x)
        elif self.activation == "tanh":
            return self.tanh(x)
        elif self.activation == "relu":
            return self.relu(x)
        else:
            return self.sigmoid(x) 
        
    # derivatives
    def derivative(self, a):

        if self.activation == "sigmoid":
            return a * (1 - a)
        elif self.activation == "tanh":
            return 1 - a**2
        elif self.activation == "relu":
            return (a > 0).astype(float)
        else:
            return a * (1 - a) 

    def softmax(self, x):
        exp_x = np.exp(x - np.max(x, axis=1, keepdims=True))
        return exp_x / np.sum(exp_x, axis=1, keepdims=True)

    # Forward Pass
    def forward_pass(self, x):
        self.h = [x]  
        # Hidden layers
        for i in range(self.layer_n - 2):
            z = np.dot(self.h[i], self.weights[i]) + self.biases[i]
            act = self.activate(z)
            self.h.append(act)
        # Output layer- softmax
        z_out = np.dot(self.h[-1], self.weights[-1]) + self.biases[-1]
        out = self.softmax(z_out)
        self.h.append(out)
        return self.h

    # Backward Pass
    def backward_prop(self, y_true):
        m = y_true.shape[0]
        dw = [None] * (self.layer_n - 1)
        db = [None] * (self.layer_n - 1)

        # Cross-entropy derivative for output layer
        if self.loss_func=="cross_entropy":
            delta = self.h[-1] - y_true  # shape: (batch_size, output_dim)
        elif self.loss_func=="sq_error":
            batch_size_sq=len(self.h[-1])
            classes_sq=len(self.h[-1][0])
            delta=np.zeros((batch_size_sq,classes_sq))

            for i in range(batch_size_sq):
                jacobian_softmax= np.diag(self.h[-1][i]) - np.outer(self.h[-1][i], self.h[-1][i])
                # print(jacobian_softmax.shape)
                # print(self.h[-1][i])    
                delta[i]= 2*np.dot(self.h[-1][i]-y_true[i], jacobian_softmax)
                
        else:
            delta = self.h[-1] - y_true 


        # Propagation
        for i in reversed(range(self.layer_n - 1)):
            dw[i] = np.dot(self.h[i].T, delta) / m
            db[i] = np.sum(delta, axis=0, keepdims=True) / m
            if i > 0:
                # For hidden layers, multiply by derivative of activation
                delta = np.dot(delta, self.weights[i].T) * self.derivative(self.h[i])
        return dw, db

    # Param Updates for "Non-Nesterov" 
    def _update_params(self, dw, db):
        # Add weight decay to each gradient
        for i in range(self.layer_n - 1):
            dw[i] += self.weight_decay * self.weights[i]

        if self.optimizer == "sgd":
            for i in range(self.layer_n - 1):
                self.weights[i] -= self.lr * dw[i]
                self.biases[i] -= self.lr * db[i]

        elif self.optimizer == "momentum":
            for i in range(self.layer_n - 1):
                self.v_w[i] = self.momentum * self.v_w[i] + dw[i]
                self.v_b[i] = self.momentum * self.v_b[i] + db[i]
                self.weights[i] -= self.lr * self.v_w[i]
                self.biases[i] -= self.lr * self.v_b[i]

        elif self.optimizer == "rmsprop":
            for i in range(self.layer_n - 1):
                self.v_w[i] = self.beta * self.v_w[i] + (1 - self.beta) * (dw[i] ** 2)
                self.v_b[i] = self.beta * self.v_b[i] + (1 - self.beta) * (db[i] ** 2)
                self.weights[i] -= self.lr * dw[i] / (np.sqrt(self.v_w[i]) + self.epsilon)
                self.biases[i]  -= self.lr * db[i] / (np.sqrt(self.v_b[i]) + self.epsilon)

        elif self.optimizer == "adam":
            self.t += 1
            for i in range(self.layer_n - 1):
                self.m_w[i] = self.beta1 * self.m_w[i] + (1 - self.beta1) * dw[i]
                self.m_b[i] = self.beta1 * self.m_b[i] + (1 - self.beta1) * db[i]
                self.v_w[i] = self.beta2 * self.v_w[i] + (1 - self.beta2) * (dw[i] ** 2)
                self.v_b[i] = self.beta2 * self.v_b[i] + (1 - self.beta2) * (db[i] ** 2)

                # bias correction
                m_w_hat = self.m_w[i] / (1 - self.beta1 ** self.t)
                m_b_hat = self.m_b[i] / (1 - self.beta1 ** self.t)
                v_w_hat = self.v_w[i] / (1 - self.beta2 ** self.t)
                v_b_hat = self.v_b[i] / (1 - self.beta2 ** self.t)

                self.weights[i] -= self.lr * m_w_hat / (np.sqrt(v_w_hat) + self.epsilon)
                self.biases[i]  -= self.lr * m_b_hat / (np.sqrt(v_b_hat) + self.epsilon)

        elif self.optimizer == "nadam":
            self.t += 1
            for i in range(self.layer_n - 1):
                self.m_w[i] = self.beta1 * self.m_w[i] + (1 - self.beta1) * dw[i]
                self.m_b[i] = self.beta1 * self.m_b[i] + (1 - self.beta1) * db[i]
                self.v_w[i] = self.beta2 * self.v_w[i] + (1 - self.beta2) * (dw[i] ** 2)
                self.v_b[i] = self.beta2 * self.v_b[i] + (1 - self.beta2) * (db[i] ** 2)

                # bias correction
                m_w_hat = self.m_w[i] / (1 - self.beta1 ** (self.t + 1))
                m_b_hat = self.m_b[i] / (1 - self.beta1 ** (self.t + 1))
                v_w_hat = self.v_w[i] / (1 - self.beta2 ** (self.t + 1))
                v_b_hat = self.v_b[i] / (1 - self.beta2 ** (self.t + 1))

                grad_term_w = self.beta1 * m_w_hat + (1 - self.beta1) * dw[i] / (1 - self.beta1 ** (self.t + 1))
                grad_term_b = self.beta1 * m_b_hat + (1 - self.beta1) * db[i] / (1 - self.beta1 ** (self.t + 1))

                self.weights[i] -= self.lr * grad_term_w / (np.sqrt(v_w_hat) + self.epsilon)
                self.biases[i]  -= self.lr * grad_term_b / (np.sqrt(v_b_hat) + self.epsilon)

    # Training Step  with "Nesterov"
    def _train_step(self, x_batch, y_batch):
        if self.optimizer == "nesterov":
            # to look-ahead: w_look = w - momentum * v
            for i in range(self.layer_n - 1):
                self.weights[i] -= self.lr*self.momentum * self.v_w[i]
                self.biases[i]  -= self.lr*self.momentum * self.v_b[i]

            # Forward at the look-ahead position
            self.forward_pass(x_batch)
            out = self.h[-1]
            l2_norm_weights = 0
            for i in range(len(self.weights)):
                l2_norm_weights += np.sum(self.weights[i] ** 2)
            # for i in range(len(self.biases)):
            #     l2_norm_bias += np.sum(self.biases[i] ** 2)
                    
            l2_norm_params = l2_norm_weights #+ l2_norm_bias

            if self.loss_func=="cross_entropy":
                loss = -np.mean(np.sum(y_batch * np.log(out + 1e-10), axis = 1)) +  (self.weight_decay/2) * l2_norm_params # (1e-10) to prevent underflow
            elif self.loss_func=="sq_error" :
                loss= 0.5 * np.mean(np.sum((out - y_batch)**2, axis=1))
            else:
                loss = -np.mean(np.sum(y_batch * np.log(out + 1e-10), axis = 1)) +  (self.weight_decay/2) * l2_norm_params
            
            
            #loss = -np.mean(np.sum(y_batch * np.log(out + 1e-10), axis = 1)) +  (self.weight_decay/2) * l2_norm_params # (1e-10) to prevent underflow
            #loss = -np.mean(np.sum(y_batch * np.log(out + 1e-10), axis=1))
            dW, dB = self.backward_prop(y_batch)

            # add weight decay here
            for i in range(self.layer_n - 1):
                dW[i] += self.weight_decay * self.weights[i]

            # backward at the look-ahead position (go back to w_t)
            for i in range(self.layer_n - 1):
                self.weights[i] += self.lr*self.momentum * self.v_w[i]
                self.biases[i]  += self.lr*self.momentum * self.v_b[i]

            # update velocity: u_t = momentum*u_{t-1} + dW
            for i in range(self.layer_n - 1):
                self.v_w[i] = self.momentum * self.v_w[i] + dW[i]
                self.v_b[i] = self.momentum * self.v_b[i] + dB[i]

            # final param update: w = w - lr*u_t
            for i in range(self.layer_n - 1):
                self.weights[i] -= self.lr * self.v_w[i]
                self.biases[i]  -= self.lr * self.v_b[i]

            return loss
        else:
            # Normal forward/back
            self.forward_pass(x_batch)
            out = self.h[-1]

            l2_norm_weights=0
            
            for i in range(len(self.weights)):
                l2_norm_weights += np.sum(self.weights[i] ** 2)
            # for i in range(len(self.biases)):
            #     l2_norm_bias += np.sum(self.biases[i] ** 2)
                    
            l2_norm_params = l2_norm_weights #+ l2_norm_bias

            if self.loss_func=="cross_entropy":
                loss = -np.mean(np.sum(y_batch * np.log(out + 1e-10), axis = 1)) +  (self.weight_decay/2) * l2_norm_params # (1e-10) to prevent underflow
            elif self.loss_func=="sq_error" :
                loss= 0.5 * np.mean(np.sum((out - y_batch)**2, axis=1))
            else:
                loss = -np.mean(np.sum(y_batch * np.log(out + 1e-10), axis = 1)) +  (self.weight_decay/2) * l2_norm_params    
            
            
             

            #loss = -np.mean(np.sum(y_batch * np.log(out + 1e-10), axis=1))
            dW, dB = self.backward_prop(y_batch)
            self._update_params(dW, dB)
            return loss

    # Outer Training Loop 
    def training(self, x_train, y_train, x_val, y_val, epochs, batch_size):
       
        for ep in range(epochs):
            idx = np.random.permutation(x_train.shape[0])
            x_train_shuff = x_train[idx]
            y_train_shuff = y_train[idx]
            n_batches = len(x_train) // batch_size
            epoch_loss = 0.0
            for b in range(n_batches):
                start = b * batch_size
                end = start + batch_size
                x_batch = x_train_shuff[start:end]
                y_batch = y_train_shuff[start:end]
                loss = self._train_step(x_batch, y_batch)
                epoch_loss += loss
            avg_loss = epoch_loss / n_batches

            # Validation

            preds = self.predict(x_val)
            val_labels = np.argmax(y_val, axis=1)
            val_acc = np.mean(preds == val_labels)

            val_outputs = self.forward_pass(x_val)[-1]
        
            # Cross-entropy loss for validation
            #val_loss = -np.mean(np.sum(y_val * np.log(val_outputs + 1e-10), axis=1))
            # training
            preds_train = self.predict(x_train)
            train_labels = np.argmax(y_train, axis=1)
            train_acc = np.mean(preds_train == train_labels)

            l2_norm_weights=0
            
            for i in range(len(self.weights)):
                l2_norm_weights += np.sum(self.weights[i] ** 2)
            # for i in range(len(self.biases)):
            #     l2_norm_bias += np.sum(self.biases[i] ** 2)
                    
            l2_norm_params = l2_norm_weights

            if self.loss_func=="cross_entropy":
                val_loss = -np.mean(np.sum(y_val * np.log(val_outputs + 1e-10), axis = 1)) +  (self.weight_decay/2) * l2_norm_params # (1e-10) to prevent underflow
            elif self.loss_func=="sq_error" :
                val_loss= 0.5 * np.mean(np.sum((val_outputs - y_val)**2, axis=1))
            else:
                val_loss = -np.mean(np.sum(y_val * np.log(val_outputs + 1e-10), axis = 1)) +  (self.weight_decay/2) * l2_norm_params

            # Log metrics to wandb
            wandb.log({"epoch": ep+1, "training_loss": avg_loss, "validation_accuracy": val_acc, "training accuracy": train_acc, "validation loss": val_loss})
            print(f"Epoch {ep+1}/{epochs} - loss={avg_loss:.4f}, val_acc={val_acc:.4f}, val_loss={val_loss}" )

    #Prediction 
    def predict(self, X):
        self.forward_pass(X)
        return np.argmax(self.h[-1], axis=1)




# train_sweep() function

def train_sweep():
    # Initialize wandb
    wandb.init()
    config = wandb.config

    #custom run name from hyperparameters

    run_name = f"hl_{config.num_layers}_hs_{config.hidden_size}_bs_{config.batch_size}_ac_{config.activation}_opt_{config.optimizer}"
    wandb.run.name = run_name

    if config["dataset"] == "fashion_mnist":
        (x_train_full, y_train_full), (x_test, y_test) = fashion_mnist.load_data()
    else:  # "mnist"
        (x_train_full, y_train_full), (x_test, y_test) = mnist.load_data()

    x_train_full = x_train_full.reshape(x_train_full.shape[0], -1) / 255.0
    x_test = x_test.reshape(x_test.shape[0], -1) / 255.0

    np.random.seed(42)
    idx = np.arange(x_train_full.shape[0])
    np.random.shuffle(idx)
    x_train_full = x_train_full[idx]
    y_train_full = y_train_full[idx]

    # 90% train, 10% validation
    train_size = int(0.9 * len(x_train_full))
    x_train, y_train = x_train_full[:train_size], y_train_full[:train_size]
    x_val, y_val = x_train_full[train_size:], y_train_full[train_size:]

    num_classes = 10
    y_train_1h = np.eye(num_classes)[y_train]
    y_val_1h = np.eye(num_classes)[y_val]
    y_test_1h = np.eye(num_classes)[y_test]

    # Build model
    # layers = [784] + [hidden_size] * num_layers + [10]
    model = feed_forward_NN_8b(
        layers=[784] + [config["hidden_size"]] * config["num_layers"] + [10],
        optimizer=config["optimizer"],
        learning_rate=config["learning_rate"],
        momentum=config["momentum"],
        beta1=config["beta1"],
        beta2=config["beta2"],
        beta=config["beta"],
        epsilon=config["epsilon"],
        weight_decay=config["weight_decay"],
        weight_init=config["weight_init"],
        activation=config["activation"],
        loss=config["loss"],
    )

    # Train
    model.training(
        x_train=x_train,
        y_train=y_train_1h,
        x_val=x_val,
        y_val=y_val_1h,
        epochs=config["epochs"],
        batch_size=config["batch_size"],
    )

    #Evaluation on test set
    test_preds = model.predict(x_test)
    test_labels = np.argmax(y_test_1h, axis=1)
    test_acc = np.mean(test_preds == test_labels)
    
    wandb.log({"test_accuracy": test_acc})
    print("test accuracy ",test_acc)


# sweep configuration
sweep_config = {
    "method": "random", 
    "metric": {
        "name": "validation_accuracy",
        "goal": "maximize"
    },
    "parameters": {
        "epochs": {"values": [5,10]},
        "num_layers": {"values": [3,4,5]},
        "hidden_size": {"values": [32,16,64]},
        "weight_decay": {"values": [0.0, 0.0005, 0.5]},
        "learning_rate": {"values": [1e-3, 1e-4]},
        "optimizer": {"values": ["sgd", "momentum", "nag", "rmsprop", "adam", "nadam"]},
        "batch_size": {"values": [32,64,128]},
        "init_type": {"values": ["random","xavier"]},
        "activation": {"values": [ "tanh", "relu","sigmoid"]},
        "momentum": {"values": [0.9]},
        "beta1": {"values": [0.9]},
        "beta2": {"values": [0.999]},
        "beta_rms": {"values": [0.9]},
        "epsilon": {"values": [1e-8]},
        "loss_func":{"values":["cross_entropy"]},
        "dataset":{"values":["fashion_mnist"]}
    }
}


# Running the sweep



if __name__ == "__main__":
    # Creating sweep
    sweep_id = wandb.sweep(sweep_config, project="q4_sweep_project")
    # Launching sweep agent
    wandb.agent(sweep_id, function=train_sweep)
# Out:
# Create sweep with ID: jl0s4l1o
# Sweep URL: https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/jl0s4l1o
# wandb: Network error (SSLError), entering retry loop.
# wandb: Agent Starting Run: z4mu7ngb with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 128
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	beta_rms: 0.9
# wandb: 	dataset: fashion_mnist
# wandb: 	epochs: 10
# wandb: 	epsilon: 1e-08
# wandb: 	hidden_size: 64
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	momentum: 0.9
# wandb: 	num_layers: 4
# wandb: 	optimizer: momentum
# wandb: 	weight_decay: 0.5
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\acer\OneDrive\Documents\GitHub\dl_assignment_ed24s401\wandb\run-20250317_222344-z4mu7ngb</code>
# Syncing run <strong><a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/z4mu7ngb' target="_blank">genial-sweep-1</a></strong> to <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/jl0s4l1o' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/jl0s4l1o</a>
#  View project at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a>
#  View sweep at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/jl0s4l1o' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/jl0s4l1o</a>
#  View run at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/z4mu7ngb' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/z4mu7ngb</a>
#  View run <strong style="color:#cdcd00">hl_4_hs_64_bs_128_ac_relu_opt_momentum</strong> at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/z4mu7ngb' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/z4mu7ngb</a><br> View project at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_222344-z4mu7ngb\logs</code>
# Run z4mu7ngb errored:
# Traceback (most recent call last):
#   File "c:\Users\acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\agents\pyagent.py", line 306, in _run_job
#     self._function()
#   File "C:\Users\acer\AppData\Local\Temp\ipykernel_24364\153520030.py", line 393, in train_sweep
#     beta=config["beta"],
#          ~~~~~~^^^^^^^^
#   File "c:\Users\acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\wandb_config.py", line 130, in __getitem__
#     return self._items[key]
#            ~~~~~~~~~~~^^^^^
# KeyError: 'beta'
#
# wandb: ERROR Run z4mu7ngb errored:
# wandb: ERROR Traceback (most recent call last):
# wandb: ERROR   File "c:\Users\acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\agents\pyagent.py", line 306, in _run_job
# wandb: ERROR     self._function()
# wandb: ERROR   File "C:\Users\acer\AppData\Local\Temp\ipykernel_24364\153520030.py", line 393, in train_sweep
# wandb: ERROR     beta=config["beta"],
# wandb: ERROR          ~~~~~~^^^^^^^^
# wandb: ERROR   File "c:\Users\acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\wandb_config.py", line 130, in __getitem__
# wandb: ERROR     return self._items[key]
# wandb: ERROR            ~~~~~~~~~~~^^^^^
# wandb: ERROR KeyError: 'beta'
# wandb: ERROR
# wandb: Agent Starting Run: vgq4ktau with config:
# wandb: 	activation: tanh
# wandb: 	batch_size: 64
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	beta_rms: 0.9
# wandb: 	dataset: fashion_mnist
# wandb: 	epochs: 5
# wandb: 	epsilon: 1e-08
# wandb: 	hidden_size: 32
# wandb: 	init_type: xavier
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	momentum: 0.9
# wandb: 	num_layers: 5
# wandb: 	optimizer: sgd
# wandb: 	weight_decay: 0.0005
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\acer\OneDrive\Documents\GitHub\dl_assignment_ed24s401\wandb\run-20250317_222359-vgq4ktau</code>
# Syncing run <strong><a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/vgq4ktau' target="_blank">pleasant-sweep-2</a></strong> to <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/jl0s4l1o' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/jl0s4l1o</a>
#  View project at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a>
#  View sweep at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/jl0s4l1o' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/jl0s4l1o</a>
#  View run at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/vgq4ktau' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/vgq4ktau</a>
#  View run <strong style="color:#cdcd00">hl_5_hs_32_bs_64_ac_tanh_opt_sgd</strong> at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/vgq4ktau' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/vgq4ktau</a><br> View project at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_222359-vgq4ktau\logs</code>
# Run vgq4ktau errored:
# Traceback (most recent call last):
#   File "c:\Users\acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\agents\pyagent.py", line 306, in _run_job
#     self._function()
#   File "C:\Users\acer\AppData\Local\Temp\ipykernel_24364\153520030.py", line 393, in train_sweep
#     beta=config["beta"],
#          ~~~~~~^^^^^^^^
#   File "c:\Users\acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\wandb_config.py", line 130, in __getitem__
#     return self._items[key]
#            ~~~~~~~~~~~^^^^^
# KeyError: 'beta'
#
# wandb: ERROR Run vgq4ktau errored:
# wandb: ERROR Traceback (most recent call last):
# wandb: ERROR   File "c:\Users\acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\agents\pyagent.py", line 306, in _run_job
# wandb: ERROR     self._function()
# wandb: ERROR   File "C:\Users\acer\AppData\Local\Temp\ipykernel_24364\153520030.py", line 393, in train_sweep
# wandb: ERROR     beta=config["beta"],
# wandb: ERROR          ~~~~~~^^^^^^^^
# wandb: ERROR   File "c:\Users\acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\wandb_config.py", line 130, in __getitem__
# wandb: ERROR     return self._items[key]
# wandb: ERROR            ~~~~~~~~~~~^^^^^
# wandb: ERROR KeyError: 'beta'
# wandb: ERROR
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: uyv586k2 with config:
# wandb: 	activation: sigmoid
# wandb: 	batch_size: 32
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	beta_rms: 0.9
# wandb: 	dataset: fashion_mnist
# wandb: 	epochs: 10
# wandb: 	epsilon: 1e-08
# wandb: 	hidden_size: 16
# wandb: 	init_type: xavier
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	momentum: 0.9
# wandb: 	num_layers: 4
# wandb: 	optimizer: nag
# wandb: 	weight_decay: 0.5
# creating run (0.4s)
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\acer\OneDrive\Documents\GitHub\dl_assignment_ed24s401\wandb\run-20250317_222428-uyv586k2</code>
# Syncing run <strong><a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/uyv586k2' target="_blank">rich-sweep-3</a></strong> to <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/jl0s4l1o' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/jl0s4l1o</a>
#  View project at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a>
#  View sweep at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/jl0s4l1o' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/jl0s4l1o</a>
#  View run at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/uyv586k2' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/uyv586k2</a>
#  View run <strong style="color:#cdcd00">hl_4_hs_16_bs_32_ac_sigmoid_opt_nag</strong> at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/uyv586k2' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/uyv586k2</a><br> View project at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_222428-uyv586k2\logs</code>
# Run uyv586k2 errored:
# Traceback (most recent call last):
#   File "c:\Users\acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\agents\pyagent.py", line 306, in _run_job
#     self._function()
#   File "C:\Users\acer\AppData\Local\Temp\ipykernel_24364\153520030.py", line 393, in train_sweep
#     beta=config["beta"],
#          ~~~~~~^^^^^^^^
#   File "c:\Users\acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\wandb_config.py", line 130, in __getitem__
#     return self._items[key]
#            ~~~~~~~~~~~^^^^^
# KeyError: 'beta'
#
# wandb: ERROR Run uyv586k2 errored:
# wandb: ERROR Traceback (most recent call last):
# wandb: ERROR   File "c:\Users\acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\agents\pyagent.py", line 306, in _run_job
# wandb: ERROR     self._function()
# wandb: ERROR   File "C:\Users\acer\AppData\Local\Temp\ipykernel_24364\153520030.py", line 393, in train_sweep
# wandb: ERROR     beta=config["beta"],
# wandb: ERROR          ~~~~~~^^^^^^^^
# wandb: ERROR   File "c:\Users\acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\wandb_config.py", line 130, in __getitem__
# wandb: ERROR     return self._items[key]
# wandb: ERROR            ~~~~~~~~~~~^^^^^
# wandb: ERROR KeyError: 'beta'
# wandb: ERROR
# wandb: Agent Starting Run: 0pekahxd with config:
# wandb: 	activation: tanh
# wandb: 	batch_size: 64
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	beta_rms: 0.9
# wandb: 	dataset: fashion_mnist
# wandb: 	epochs: 5
# wandb: 	epsilon: 1e-08
# wandb: 	hidden_size: 32
# wandb: 	init_type: xavier
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	momentum: 0.9
# wandb: 	num_layers: 5
# wandb: 	optimizer: nadam
# wandb: 	weight_decay: 0.5
# creating run (0.4s)
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\acer\OneDrive\Documents\GitHub\dl_assignment_ed24s401\wandb\run-20250317_222437-0pekahxd</code>
# Syncing run <strong><a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/0pekahxd' target="_blank">frosty-sweep-4</a></strong> to <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/jl0s4l1o' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/jl0s4l1o</a>
#  View project at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a>
#  View sweep at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/jl0s4l1o' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/jl0s4l1o</a>
#  View run at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/0pekahxd' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/0pekahxd</a>
#  View run <strong style="color:#cdcd00">hl_5_hs_32_bs_64_ac_tanh_opt_nadam</strong> at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/0pekahxd' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/0pekahxd</a><br> View project at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_222437-0pekahxd\logs</code>
# Run 0pekahxd errored:
# Traceback (most recent call last):
#   File "c:\Users\acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\agents\pyagent.py", line 306, in _run_job
#     self._function()
#   File "C:\Users\acer\AppData\Local\Temp\ipykernel_24364\153520030.py", line 393, in train_sweep
#     beta=config["beta"],
#          ~~~~~~^^^^^^^^
#   File "c:\Users\acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\wandb_config.py", line 130, in __getitem__
#     return self._items[key]
#            ~~~~~~~~~~~^^^^^
# KeyError: 'beta'
#
# wandb: ERROR Run 0pekahxd errored:
# wandb: ERROR Traceback (most recent call last):
# wandb: ERROR   File "c:\Users\acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\agents\pyagent.py", line 306, in _run_job
# wandb: ERROR     self._function()
# wandb: ERROR   File "C:\Users\acer\AppData\Local\Temp\ipykernel_24364\153520030.py", line 393, in train_sweep
# wandb: ERROR     beta=config["beta"],
# wandb: ERROR          ~~~~~~^^^^^^^^
# wandb: ERROR   File "c:\Users\acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\wandb_config.py", line 130, in __getitem__
# wandb: ERROR     return self._items[key]
# wandb: ERROR            ~~~~~~~~~~~^^^^^
# wandb: ERROR KeyError: 'beta'
# wandb: ERROR
# wandb: Agent Starting Run: eqjwuii7 with config:
# wandb: 	activation: tanh
# wandb: 	batch_size: 64
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	beta_rms: 0.9
# wandb: 	dataset: fashion_mnist
# wandb: 	epochs: 5
# wandb: 	epsilon: 1e-08
# wandb: 	hidden_size: 32
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	momentum: 0.9
# wandb: 	num_layers: 4
# wandb: 	optimizer: nag
# wandb: 	weight_decay: 0.5
# creating run (0.2s)
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\acer\OneDrive\Documents\GitHub\dl_assignment_ed24s401\wandb\run-20250317_222448-eqjwuii7</code>
# Syncing run <strong><a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/eqjwuii7' target="_blank">vocal-sweep-5</a></strong> to <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/jl0s4l1o' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/jl0s4l1o</a>
#  View project at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a>
#  View sweep at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/jl0s4l1o' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/jl0s4l1o</a>
#  View run at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/eqjwuii7' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/eqjwuii7</a>
#  View run <strong style="color:#cdcd00">hl_4_hs_32_bs_64_ac_tanh_opt_nag</strong> at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/eqjwuii7' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/eqjwuii7</a><br> View project at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_222448-eqjwuii7\logs</code>
# Run eqjwuii7 errored:
# Traceback (most recent call last):
#   File "c:\Users\acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\agents\pyagent.py", line 306, in _run_job
#     self._function()
#   File "C:\Users\acer\AppData\Local\Temp\ipykernel_24364\153520030.py", line 393, in train_sweep
#     beta=config["beta"],
#          ~~~~~~^^^^^^^^
#   File "c:\Users\acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\wandb_config.py", line 130, in __getitem__
#     return self._items[key]
#            ~~~~~~~~~~~^^^^^
# KeyError: 'beta'
#
# wandb: ERROR Run eqjwuii7 errored:
# wandb: ERROR Traceback (most recent call last):
# wandb: ERROR   File "c:\Users\acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\agents\pyagent.py", line 306, in _run_job
# wandb: ERROR     self._function()
# wandb: ERROR   File "C:\Users\acer\AppData\Local\Temp\ipykernel_24364\153520030.py", line 393, in train_sweep
# wandb: ERROR     beta=config["beta"],
# wandb: ERROR          ~~~~~~^^^^^^^^
# wandb: ERROR   File "c:\Users\acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\wandb_config.py", line 130, in __getitem__
# wandb: ERROR     return self._items[key]
# wandb: ERROR            ~~~~~~~~~~~^^^^^
# wandb: ERROR KeyError: 'beta'
# wandb: ERROR
# wandb: Agent Starting Run: wfx4nk6n with config:
# wandb: 	activation: tanh
# wandb: 	batch_size: 64
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.999
# wandb: 	beta_rms: 0.9
# wandb: 	dataset: fashion_mnist
# wandb: 	epochs: 5
# wandb: 	epsilon: 1e-08
# wandb: 	hidden_size: 32
# wandb: 	init_type: xavier
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	momentum: 0.9
# wandb: 	num_layers: 5
# wandb: 	optimizer: sgd
# wandb: 	weight_decay: 0
# creating run (0.4s)
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\acer\OneDrive\Documents\GitHub\dl_assignment_ed24s401\wandb\run-20250317_222458-wfx4nk6n</code>
# Syncing run <strong><a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/wfx4nk6n' target="_blank">exalted-sweep-6</a></strong> to <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/jl0s4l1o' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/jl0s4l1o</a>
#  View project at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a>
#  View sweep at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/jl0s4l1o' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/sweeps/jl0s4l1o</a>
#  View run at <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/wfx4nk6n' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/wfx4nk6n</a>
#  View run <strong style="color:#cdcd00">hl_5_hs_32_bs_64_ac_tanh_opt_sgd</strong> at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/wfx4nk6n' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project/runs/wfx4nk6n</a><br> View project at: <a href='https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project' target="_blank">https://wandb.ai/ed24s401-indian-institute-of-technology-madras/q4_sweep_project</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250317_222458-wfx4nk6n\logs</code>
# Run wfx4nk6n errored:
# Traceback (most recent call last):
#   File "c:\Users\acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\agents\pyagent.py", line 306, in _run_job
#     self._function()
#   File "C:\Users\acer\AppData\Local\Temp\ipykernel_24364\153520030.py", line 393, in train_sweep
#     beta=config["beta"],
#          ~~~~~~^^^^^^^^
#   File "c:\Users\acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\wandb_config.py", line 130, in __getitem__
#     return self._items[key]
#            ~~~~~~~~~~~^^^^^
# KeyError: 'beta'
#
# wandb: ERROR Run wfx4nk6n errored:
# wandb: ERROR Traceback (most recent call last):
# wandb: ERROR   File "c:\Users\acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\agents\pyagent.py", line 306, in _run_job
# wandb: ERROR     self._function()
# wandb: ERROR   File "C:\Users\acer\AppData\Local\Temp\ipykernel_24364\153520030.py", line 393, in train_sweep
# wandb: ERROR     beta=config["beta"],
# wandb: ERROR          ~~~~~~^^^^^^^^
# wandb: ERROR   File "c:\Users\acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\wandb_config.py", line 130, in __getitem__
# wandb: ERROR     return self._items[key]
# wandb: ERROR            ~~~~~~~~~~~^^^^^
# wandb: ERROR KeyError: 'beta'
# wandb: ERROR
# Detected 5 failed runs in a row at start, killing sweep.
# wandb: ERROR Detected 5 failed runs in a row at start, killing sweep.
# wandb: To change this value set WANDB_AGENT_MAX_INITIAL_FAILURES=val
